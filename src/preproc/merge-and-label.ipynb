# %%
import os
import sys
import h5py
import getpass

from golden_json import GoldenJson

# %%
# Permission for eos
os.system("echo %s | kinit" % getpass.getpass())
# Out:
# ········
# 0

# %%
# Init variables

dset_name = "ZeroBias2016"
dset_name = "JetHT2016"
dset_name = "SingleMuon2016"
dset_name = "SinglePhoton2016"

# Source directory of original h5 datasets
data_src = "/home/mantydze/data/{dset_name}/original".format(dset_name=dset_name)

# Destinaton directory for a merged dataset
data_dst = "/home/mantydze/data/{dset_name}/single/{dset_name}.h5".format(dset_name=dset_name) 

# Golden JSON location
golden_json_path = "../../data/Cert_271036-284044_13TeV_PromptReco_Collisions16_JSON.txt"

gj = GoldenJson(golden_json_path)

# %%
def get_sub_dset(filename):
    """
        Read sub dataset (_background, _signal) 
        Apply Golden JSON (Overwrite existing label with one from GoldenJSON)
        Return dataset with new labels
    """
    
    print(filename, flush=True)
    sub_dset = None
    
    with h5py.File("%s/%s" % (data_src, filename), "r") as sub_h5:
        sub_dset_name = filename.replace(".h5", "")
        sub_dset = sub_h5[sub_dset_name][:]
        rows_count = sub_dset.shape[0] # rows count
        
        print ("Rows: %d" % rows_count, flush=True)
        
        for row_index in range(rows_count):
            run_number = int(sub_dset[row_index, 2807])
            lumi_section = int(sub_dset[row_index, 2808])
            
            label_orig = int(sub_dset[row_index, 2812]) # inversed (1 - bad, 0 - good)
            label_gj = gj.is_good(run_number, lumi_section)
            
            # Assign new label
            sub_dset[row_index, 2812] = label_gj
            
            # Print both old(original) and new(GoldenJSON) labels if they differ
            if (label_orig == label_gj):
                print("%d) Run %d | LS %d | Orig %d | GoldenJSON %d" % (row_index, run_number, lumi_section, label_orig, label_gj))
                
    return sub_dset

# %%
# %%time

with h5py.File(data_dst, "w") as main_h5:
    main_dset = None

    total_rows_count = 0
    # Iterate all datasets in a directory
    for filename in os.listdir(data_src):
        
        # Get dataset with good labels
        sub_dset = get_sub_dset(filename)
        sub_rows_count = sub_dset.shape[0] # rows count
        
        total_rows_count += sub_rows_count
        
        # Append sub dataset into final dataset
        if main_dset is None:
            main_dset = main_h5.create_dataset(dset_name, chunks=True, dtype="float64", 
                                               maxshape=(None, None), data=sub_dset[:], 
                                               compression="gzip", compression_opts=0)
        else:
            main_dset.resize(main_dset.shape[0] + sub_rows_count, axis=0)
            main_dset[-sub_rows_count:] = sub_dset[:]

    print("Total row count: %d" % total_rows_count)
    print("Main dset:")
    print(main_dset.shape)
# Out:
# SinglePhoton_C_background.h5
# Rows: 474
# 111) Run 276095 | LS 1 | Orig 0 | GoldenJSON 0
# 112) Run 276095 | LS 2 | Orig 0 | GoldenJSON 0
# 113) Run 276095 | LS 3 | Orig 0 | GoldenJSON 0
# 114) Run 276095 | LS 4 | Orig 0 | GoldenJSON 0
# 115) Run 276095 | LS 5 | Orig 0 | GoldenJSON 0
# 168) Run 275833 | LS 116 | Orig 0 | GoldenJSON 0
# 186) Run 275922 | LS 4 | Orig 0 | GoldenJSON 0
# 187) Run 275922 | LS 5 | Orig 0 | GoldenJSON 0
# 188) Run 275922 | LS 6 | Orig 0 | GoldenJSON 0
# 201) Run 275911 | LS 355 | Orig 0 | GoldenJSON 0
# 210) Run 275757 | LS 108 | Orig 0 | GoldenJSON 0
# 211) Run 275757 | LS 109 | Orig 0 | GoldenJSON 0
# 212) Run 275757 | LS 110 | Orig 0 | GoldenJSON 0
# 213) Run 275757 | LS 111 | Orig 0 | GoldenJSON 0
# 214) Run 275757 | LS 112 | Orig 0 | GoldenJSON 0
# 215) Run 275757 | LS 113 | Orig 0 | GoldenJSON 0
# 216) Run 275757 | LS 114 | Orig 0 | GoldenJSON 0
# 217) Run 275757 | LS 115 | Orig 0 | GoldenJSON 0
# 218) Run 275757 | LS 116 | Orig 0 | GoldenJSON 0
# 219) Run 275757 | LS 117 | Orig 0 | GoldenJSON 0
# 220) Run 275757 | LS 118 | Orig 0 | GoldenJSON 0
# 221) Run 275757 | LS 119 | Orig 0 | GoldenJSON 0
# 222) Run 275757 | LS 120 | Orig 0 | GoldenJSON 0
# 223) Run 275757 | LS 121 | Orig 0 | GoldenJSON 0
# 224) Run 275757 | LS 122 | Orig 0 | GoldenJSON 0
# 225) Run 275758 | LS 1 | Orig 0 | GoldenJSON 0
# 226) Run 275758 | LS 2 | Orig 0 | GoldenJSON 0
# 227) Run 275758 | LS 3 | Orig 0 | GoldenJSON 0
# 228) Run 275758 | LS 4 | Orig 0 | GoldenJSON 0
# 229) Run 275759 | LS 1 | Orig 0 | GoldenJSON 0
# 230) Run 275759 | LS 2 | Orig 0 | GoldenJSON 0
# 231) Run 275759 | LS 3 | Orig 0 | GoldenJSON 0
# 235) Run 275759 | LS 4 | Orig 0 | GoldenJSON 0
# 236) Run 275759 | LS 5 | Orig 0 | GoldenJSON 0
# 237) Run 275759 | LS 6 | Orig 0 | GoldenJSON 0
# 242) Run 275963 | LS 140 | Orig 0 | GoldenJSON 0
# 420) Run 275911 | LS 299 | Orig 0 | GoldenJSON 0
# 425) Run 275757 | LS 106 | Orig 0 | GoldenJSON 0
# 426) Run 275757 | LS 107 | Orig 0 | GoldenJSON 0
# SinglePhoton_C_signal.h5
# Rows: 17416
# 1066) Run 275836 | LS 1171 | Orig 0 | GoldenJSON 0
# 1067) Run 275836 | LS 1172 | Orig 0 | GoldenJSON 0
# 1226) Run 275921 | LS 21 | Orig 0 | GoldenJSON 0
# 1227) Run 275921 | LS 22 | Orig 0 | GoldenJSON 0
# 1304) Run 275836 | LS 1179 | Orig 0 | GoldenJSON 0
# 1305) Run 275836 | LS 1180 | Orig 0 | GoldenJSON 0
# 2748) Run 275836 | LS 1173 | Orig 0 | GoldenJSON 0
# 2749) Run 275836 | LS 1174 | Orig 0 | GoldenJSON 0
# 2801) Run 275836 | LS 1181 | Orig 0 | GoldenJSON 0
# 2802) Run 275836 | LS 1182 | Orig 0 | GoldenJSON 0
# 2928) Run 275836 | LS 1175 | Orig 0 | GoldenJSON 0
# 2929) Run 275836 | LS 1176 | Orig 0 | GoldenJSON 0
# 3203) Run 275836 | LS 1177 | Orig 0 | GoldenJSON 0
# 3204) Run 275836 | LS 1178 | Orig 0 | GoldenJSON 0
# 3216) Run 275836 | LS 1183 | Orig 0 | GoldenJSON 0
# 5908) Run 275923 | LS 65 | Orig 0 | GoldenJSON 0
# 6477) Run 275931 | LS 16 | Orig 0 | GoldenJSON 0
# 6478) Run 275931 | LS 17 | Orig 0 | GoldenJSON 0
# 6479) Run 275931 | LS 18 | Orig 0 | GoldenJSON 0
# 6935) Run 275923 | LS 58 | Orig 0 | GoldenJSON 0
# 6936) Run 275923 | LS 59 | Orig 0 | GoldenJSON 0
# 6937) Run 275923 | LS 60 | Orig 0 | GoldenJSON 0
# 6938) Run 275923 | LS 61 | Orig 0 | GoldenJSON 0
# 6939) Run 275923 | LS 62 | Orig 0 | GoldenJSON 0
# 7768) Run 275921 | LS 11 | Orig 0 | GoldenJSON 0
# 7769) Run 275921 | LS 12 | Orig 0 | GoldenJSON 0
# 7770) Run 275921 | LS 13 | Orig 0 | GoldenJSON 0
# 7771) Run 275921 | LS 14 | Orig 0 | GoldenJSON 0
# 7772) Run 275921 | LS 15 | Orig 0 | GoldenJSON 0
# 7842) Run 275918 | LS 343 | Orig 0 | GoldenJSON 0
# 7843) Run 275918 | LS 344 | Orig 0 | GoldenJSON 0
# 7844) Run 275918 | LS 345 | Orig 0 | GoldenJSON 0
# 7845) Run 275918 | LS 346 | Orig 0 | GoldenJSON 0
# 7846) Run 275918 | LS 347 | Orig 0 | GoldenJSON 0
# 8035) Run 275921 | LS 6 | Orig 0 | GoldenJSON 0
# 8036) Run 275921 | LS 7 | Orig 0 | GoldenJSON 0
# 8037) Run 275921 | LS 8 | Orig 0 | GoldenJSON 0
# 8038) Run 275921 | LS 9 | Orig 0 | GoldenJSON 0
# 8039) Run 275921 | LS 10 | Orig 0 | GoldenJSON 0
# 8640) Run 275918 | LS 336 | Orig 0 | GoldenJSON 0
# 8641) Run 275918 | LS 337 | Orig 0 | GoldenJSON 0
# 8642) Run 275918 | LS 338 | Orig 0 | GoldenJSON 0
# 8643) Run 275918 | LS 339 | Orig 0 | GoldenJSON 0
# 8644) Run 275918 | LS 340 | Orig 0 | GoldenJSON 0
# 8645) Run 275918 | LS 341 | Orig 0 | GoldenJSON 0
# 8646) Run 275918 | LS 342 | Orig 0 | GoldenJSON 0
# 8962) Run 276242 | LS 8 | Orig 0 | GoldenJSON 0
# 8963) Run 276242 | LS 9 | Orig 0 | GoldenJSON 0
# 8964) Run 276242 | LS 10 | Orig 0 | GoldenJSON 0
# 8965) Run 276242 | LS 11 | Orig 0 | GoldenJSON 0
# 9178) Run 275918 | LS 319 | Orig 0 | GoldenJSON 0
# 9179) Run 275918 | LS 320 | Orig 0 | GoldenJSON 0
# 9180) Run 275918 | LS 321 | Orig 0 | GoldenJSON 0
# 9190) Run 275918 | LS 329 | Orig 0 | GoldenJSON 0
# 9191) Run 275918 | LS 330 | Orig 0 | GoldenJSON 0
# 9192) Run 275918 | LS 331 | Orig 0 | GoldenJSON 0
# 9193) Run 275918 | LS 332 | Orig 0 | GoldenJSON 0
# 9194) Run 275918 | LS 333 | Orig 0 | GoldenJSON 0
# 9195) Run 275918 | LS 334 | Orig 0 | GoldenJSON 0
# 9196) Run 275918 | LS 335 | Orig 0 | GoldenJSON 0
# 9266) Run 275923 | LS 127 | Orig 0 | GoldenJSON 0
# 9292) Run 275931 | LS 15 | Orig 0 | GoldenJSON 0
# 9464) Run 275921 | LS 3 | Orig 0 | GoldenJSON 0
# 9523) Run 275923 | LS 54 | Orig 0 | GoldenJSON 0
# 9524) Run 275923 | LS 55 | Orig 0 | GoldenJSON 0
# 9525) Run 275923 | LS 56 | Orig 0 | GoldenJSON 0
# 9526) Run 275923 | LS 57 | Orig 0 | GoldenJSON 0
# 9985) Run 276242 | LS 12 | Orig 0 | GoldenJSON 0
# 9986) Run 276242 | LS 13 | Orig 0 | GoldenJSON 0
# 9987) Run 276242 | LS 14 | Orig 0 | GoldenJSON 0
# 9988) Run 276242 | LS 15 | Orig 0 | GoldenJSON 0
# 9999) Run 276242 | LS 16 | Orig 0 | GoldenJSON 0
# 10000) Run 276242 | LS 17 | Orig 0 | GoldenJSON 0
# 10040) Run 276242 | LS 62 | Orig 0 | GoldenJSON 0
# 10041) Run 276242 | LS 63 | Orig 0 | GoldenJSON 0
# 10052) Run 276242 | LS 64 | Orig 0 | GoldenJSON 0
# 10053) Run 276242 | LS 65 | Orig 0 | GoldenJSON 0
# 10054) Run 276242 | LS 66 | Orig 0 | GoldenJSON 0
# 10055) Run 276242 | LS 67 | Orig 0 | GoldenJSON 0
# 15637) Run 275918 | LS 362 | Orig 0 | GoldenJSON 0
# 15704) Run 275782 | LS 132 | Orig 0 | GoldenJSON 0
# 16042) Run 276242 | LS 68 | Orig 0 | GoldenJSON 0
# 16043) Run 276242 | LS 69 | Orig 0 | GoldenJSON 0
# 16044) Run 276242 | LS 70 | Orig 0 | GoldenJSON 0
# 16045) Run 276242 | LS 71 | Orig 0 | GoldenJSON 0
# 16322) Run 275918 | LS 322 | Orig 0 | GoldenJSON 0
# 16323) Run 275918 | LS 323 | Orig 0 | GoldenJSON 0
# 16324) Run 275918 | LS 324 | Orig 0 | GoldenJSON 0
# 16325) Run 275918 | LS 325 | Orig 0 | GoldenJSON 0
# 16326) Run 275918 | LS 326 | Orig 0 | GoldenJSON 0
# 16327) Run 275918 | LS 327 | Orig 0 | GoldenJSON 0
# 16328) Run 275918 | LS 328 | Orig 0 | GoldenJSON 0
# SinglePhoton_D_background.h5
# Rows: 139
# 35) Run 276437 | LS 1075 | Orig 0 | GoldenJSON 0
# SinglePhoton_D_signal.h5
# Rows: 27689
# 6887) Run 276318 | LS 104 | Orig 0 | GoldenJSON 0
# 6888) Run 276318 | LS 105 | Orig 0 | GoldenJSON 0
# 9306) Run 276525 | LS 1607 | Orig 0 | GoldenJSON 0
# 11876) Run 276525 | LS 1620 | Orig 0 | GoldenJSON 0
# 11877) Run 276525 | LS 1621 | Orig 0 | GoldenJSON 0
# 11878) Run 276525 | LS 1622 | Orig 0 | GoldenJSON 0
# 11879) Run 276525 | LS 1623 | Orig 0 | GoldenJSON 0
# 11880) Run 276525 | LS 1624 | Orig 0 | GoldenJSON 0
# 11881) Run 276525 | LS 1625 | Orig 0 | GoldenJSON 0
# 11898) Run 276525 | LS 1608 | Orig 0 | GoldenJSON 0
# 11899) Run 276525 | LS 1609 | Orig 0 | GoldenJSON 0
# 11900) Run 276525 | LS 1610 | Orig 0 | GoldenJSON 0
# 11901) Run 276525 | LS 1611 | Orig 0 | GoldenJSON 0
# 11902) Run 276525 | LS 1612 | Orig 0 | GoldenJSON 0
# 11903) Run 276525 | LS 1613 | Orig 0 | GoldenJSON 0
# 11952) Run 276525 | LS 1614 | Orig 0 | GoldenJSON 0
# 11953) Run 276525 | LS 1615 | Orig 0 | GoldenJSON 0
# 11954) Run 276525 | LS 1616 | Orig 0 | GoldenJSON 0
# 11955) Run 276525 | LS 1617 | Orig 0 | GoldenJSON 0
# 11956) Run 276525 | LS 1618 | Orig 0 | GoldenJSON 0
# 11957) Run 276525 | LS 1619 | Orig 0 | GoldenJSON 0
# 22489) Run 276361 | LS 163 | Orig 0 | GoldenJSON 0
# 22490) Run 276361 | LS 164 | Orig 0 | GoldenJSON 0
# 22491) Run 276361 | LS 209 | Orig 0 | GoldenJSON 0
# 24072) Run 276361 | LS 162 | Orig 0 | GoldenJSON 0
# 24080) Run 276361 | LS 165 | Orig 0 | GoldenJSON 0
# 24081) Run 276361 | LS 166 | Orig 0 | GoldenJSON 0
# 27314) Run 276361 | LS 801 | Orig 0 | GoldenJSON 0
# SinglePhoton_F_background.h5
# Rows: 72
# 0) Run 278167 | LS 1661 | Orig 0 | GoldenJSON 0
# 16) Run 277992 | LS 261 | Orig 0 | GoldenJSON 0
# 17) Run 278289 | LS 43 | Orig 0 | GoldenJSON 0
# 18) Run 278240 | LS 114 | Orig 0 | GoldenJSON 0
# 19) Run 278017 | LS 98 | Orig 0 | GoldenJSON 0
# 41) Run 278017 | LS 214 | Orig 0 | GoldenJSON 0
# 52) Run 278315 | LS 255 | Orig 0 | GoldenJSON 0
# 53) Run 278315 | LS 662 | Orig 0 | GoldenJSON 0
# 56) Run 278349 | LS 402 | Orig 0 | GoldenJSON 0
# 67) Run 278406 | LS 361 | Orig 0 | GoldenJSON 0
# 68) Run 278017 | LS 513 | Orig 0 | GoldenJSON 0
# 69) Run 277981 | LS 84 | Orig 0 | GoldenJSON 0
# 70) Run 278808 | LS 446 | Orig 0 | GoldenJSON 0
# 71) Run 278808 | LS 463 | Orig 0 | GoldenJSON 0
# SinglePhoton_F_signal.h5
# Rows: 16480
# 2946) Run 278240 | LS 67 | Orig 0 | GoldenJSON 0
# 2947) Run 278240 | LS 68 | Orig 0 | GoldenJSON 0
# 2948) Run 278240 | LS 69 | Orig 0 | GoldenJSON 0
# 3345) Run 278240 | LS 65 | Orig 0 | GoldenJSON 0
# 3346) Run 278240 | LS 66 | Orig 0 | GoldenJSON 0
# 5488) Run 278308 | LS 1206 | Orig 0 | GoldenJSON 0
# 5489) Run 278308 | LS 1207 | Orig 0 | GoldenJSON 0
# 5490) Run 278308 | LS 1208 | Orig 0 | GoldenJSON 0
# 5491) Run 278308 | LS 1210 | Orig 0 | GoldenJSON 0
# 5494) Run 278308 | LS 1205 | Orig 0 | GoldenJSON 0
# 5495) Run 278308 | LS 1209 | Orig 0 | GoldenJSON 0
# 5547) Run 278308 | LS 1211 | Orig 0 | GoldenJSON 0
# 5548) Run 278308 | LS 1212 | Orig 0 | GoldenJSON 0
# 5549) Run 278308 | LS 1213 | Orig 0 | GoldenJSON 0
# 5550) Run 278308 | LS 1214 | Orig 0 | GoldenJSON 0
# 5551) Run 278308 | LS 1215 | Orig 0 | GoldenJSON 0
# 5552) Run 278308 | LS 1216 | Orig 0 | GoldenJSON 0
# 5707) Run 278308 | LS 1201 | Orig 0 | GoldenJSON 0
# 5708) Run 278308 | LS 1202 | Orig 0 | GoldenJSON 0
# 5709) Run 278308 | LS 1203 | Orig 0 | GoldenJSON 0
# 5710) Run 278308 | LS 1204 | Orig 0 | GoldenJSON 0
# 14640) Run 278018 | LS 628 | Orig 0 | GoldenJSON 0
# 14641) Run 278018 | LS 629 | Orig 0 | GoldenJSON 0
# 14685) Run 278018 | LS 641 | Orig 0 | GoldenJSON 0
# 14690) Run 278018 | LS 637 | Orig 0 | GoldenJSON 0
# 14691) Run 278018 | LS 638 | Orig 0 | GoldenJSON 0
# 14692) Run 278018 | LS 639 | Orig 0 | GoldenJSON 0
# 14693) Run 278018 | LS 640 | Orig 0 | GoldenJSON 0
# 14700) Run 278018 | LS 630 | Orig 0 | GoldenJSON 0
# 14701) Run 278018 | LS 631 | Orig 0 | GoldenJSON 0
# 14702) Run 278018 | LS 632 | Orig 0 | GoldenJSON 0
# 14703) Run 278018 | LS 633 | Orig 0 | GoldenJSON 0
# 14704) Run 278018 | LS 634 | Orig 0 | GoldenJSON 0
# 14705) Run 278018 | LS 635 | Orig 0 | GoldenJSON 0
# 14706) Run 278018 | LS 636 | Orig 0 | GoldenJSON 0
# 15151) Run 278018 | LS 1012 | Orig 0 | GoldenJSON 0
# 15152) Run 278018 | LS 1013 | Orig 0 | GoldenJSON 0
# 15153) Run 278018 | LS 1014 | Orig 0 | GoldenJSON 0
# 15154) Run 278018 | LS 1015 | Orig 0 | GoldenJSON 0
# 15155) Run 278018 | LS 1016 | Orig 0 | GoldenJSON 0
# 15156) Run 278018 | LS 1017 | Orig 0 | GoldenJSON 0
# 15157) Run 278018 | LS 1018 | Orig 0 | GoldenJSON 0
# 15177) Run 278018 | LS 1019 | Orig 0 | GoldenJSON 0
# SinglePhoton_G_background.h5
# Rows: 203
# 0) Run 278963 | LS 24 | Orig 0 | GoldenJSON 0
# 1) Run 278969 | LS 1052 | Orig 0 | GoldenJSON 0
# 2) Run 278969 | LS 1292 | Orig 0 | GoldenJSON 0
# 3) Run 279931 | LS 802 | Orig 0 | GoldenJSON 0
# 4) Run 279995 | LS 1 | Orig 0 | GoldenJSON 0
# 5) Run 279995 | LS 2 | Orig 0 | GoldenJSON 0
# 6) Run 279995 | LS 3 | Orig 0 | GoldenJSON 0
# 7) Run 279995 | LS 4 | Orig 0 | GoldenJSON 0
# 8) Run 279995 | LS 5 | Orig 0 | GoldenJSON 0
# 9) Run 279995 | LS 6 | Orig 0 | GoldenJSON 0
# 10) Run 279995 | LS 7 | Orig 0 | GoldenJSON 0
# 11) Run 279654 | LS 109 | Orig 0 | GoldenJSON 0
# 18) Run 279715 | LS 517 | Orig 0 | GoldenJSON 0
# 19) Run 279715 | LS 518 | Orig 0 | GoldenJSON 0
# 20) Run 279715 | LS 519 | Orig 0 | GoldenJSON 0
# 21) Run 279715 | LS 520 | Orig 0 | GoldenJSON 0
# 22) Run 279715 | LS 521 | Orig 0 | GoldenJSON 0
# 23) Run 279715 | LS 522 | Orig 0 | GoldenJSON 0
# 35) Run 279715 | LS 475 | Orig 0 | GoldenJSON 0
# 36) Run 279715 | LS 478 | Orig 0 | GoldenJSON 0
# 37) Run 279715 | LS 479 | Orig 0 | GoldenJSON 0
# 38) Run 279715 | LS 481 | Orig 0 | GoldenJSON 0
# 39) Run 279715 | LS 482 | Orig 0 | GoldenJSON 0
# 40) Run 279715 | LS 483 | Orig 0 | GoldenJSON 0
# 41) Run 279715 | LS 484 | Orig 0 | GoldenJSON 0
# 42) Run 279715 | LS 485 | Orig 0 | GoldenJSON 0
# 43) Run 279715 | LS 486 | Orig 0 | GoldenJSON 0
# 44) Run 279715 | LS 487 | Orig 0 | GoldenJSON 0
# 45) Run 279715 | LS 488 | Orig 0 | GoldenJSON 0
# 46) Run 279715 | LS 489 | Orig 0 | GoldenJSON 0
# 47) Run 279715 | LS 490 | Orig 0 | GoldenJSON 0
# 48) Run 279715 | LS 491 | Orig 0 | GoldenJSON 0
# 49) Run 279715 | LS 492 | Orig 0 | GoldenJSON 0
# 50) Run 279715 | LS 493 | Orig 0 | GoldenJSON 0
# 51) Run 279715 | LS 494 | Orig 0 | GoldenJSON 0
# 52) Run 279715 | LS 495 | Orig 0 | GoldenJSON 0
# 53) Run 279715 | LS 496 | Orig 0 | GoldenJSON 0
# 54) Run 279715 | LS 497 | Orig 0 | GoldenJSON 0
# 55) Run 279715 | LS 498 | Orig 0 | GoldenJSON 0
# 56) Run 279715 | LS 499 | Orig 0 | GoldenJSON 0
# 57) Run 279715 | LS 500 | Orig 0 | GoldenJSON 0
# 58) Run 279715 | LS 501 | Orig 0 | GoldenJSON 0
# 59) Run 279715 | LS 502 | Orig 0 | GoldenJSON 0
# 60) Run 279715 | LS 503 | Orig 0 | GoldenJSON 0
# 61) Run 279715 | LS 504 | Orig 0 | GoldenJSON 0
# 62) Run 279715 | LS 505 | Orig 0 | GoldenJSON 0
# 63) Run 279715 | LS 506 | Orig 0 | GoldenJSON 0
# 64) Run 279715 | LS 507 | Orig 0 | GoldenJSON 0
# 65) Run 279715 | LS 508 | Orig 0 | GoldenJSON 0
# 66) Run 279715 | LS 509 | Orig 0 | GoldenJSON 0
# 67) Run 279715 | LS 510 | Orig 0 | GoldenJSON 0
# 68) Run 279715 | LS 512 | Orig 0 | GoldenJSON 0
# 69) Run 279715 | LS 513 | Orig 0 | GoldenJSON 0
# 70) Run 279715 | LS 514 | Orig 0 | GoldenJSON 0
# 71) Run 279715 | LS 515 | Orig 0 | GoldenJSON 0
# 72) Run 279715 | LS 516 | Orig 0 | GoldenJSON 0
# 73) Run 279716 | LS 1529 | Orig 0 | GoldenJSON 0
# 96) Run 280191 | LS 782 | Orig 0 | GoldenJSON 0
# 97) Run 279931 | LS 629 | Orig 0 | GoldenJSON 0
# 98) Run 279685 | LS 94 | Orig 0 | GoldenJSON 0
# 105) Run 280015 | LS 40 | Orig 0 | GoldenJSON 0
# 142) Run 279931 | LS 1044 | Orig 0 | GoldenJSON 0
# 202) Run 280364 | LS 620 | Orig 0 | GoldenJSON 0
# SinglePhoton_G_signal.h5
# Rows: 42273
# 11000) Run 280349 | LS 248 | Orig 0 | GoldenJSON 0
# 13471) Run 280015 | LS 555 | Orig 0 | GoldenJSON 0
# 13472) Run 280015 | LS 556 | Orig 0 | GoldenJSON 0
# 13697) Run 279653 | LS 75 | Orig 0 | GoldenJSON 0
# 13698) Run 279653 | LS 76 | Orig 0 | GoldenJSON 0
# 13700) Run 279653 | LS 78 | Orig 0 | GoldenJSON 0
# 13705) Run 279653 | LS 79 | Orig 0 | GoldenJSON 0
# 13706) Run 279653 | LS 80 | Orig 0 | GoldenJSON 0
# 13707) Run 279653 | LS 81 | Orig 0 | GoldenJSON 0
# 14270) Run 280242 | LS 412 | Orig 0 | GoldenJSON 0
# 14271) Run 280242 | LS 413 | Orig 0 | GoldenJSON 0
# 22502) Run 279716 | LS 863 | Orig 0 | GoldenJSON 0
# 22503) Run 279716 | LS 864 | Orig 0 | GoldenJSON 0
# 22504) Run 279716 | LS 865 | Orig 0 | GoldenJSON 0
# 22505) Run 279716 | LS 866 | Orig 0 | GoldenJSON 0
# 22506) Run 279716 | LS 867 | Orig 0 | GoldenJSON 0
# 22507) Run 279716 | LS 868 | Orig 0 | GoldenJSON 0
# 22508) Run 279716 | LS 869 | Orig 0 | GoldenJSON 0
# 22509) Run 279716 | LS 870 | Orig 0 | GoldenJSON 0
# 22867) Run 279716 | LS 861 | Orig 0 | GoldenJSON 0
# 22868) Run 279716 | LS 862 | Orig 0 | GoldenJSON 0
# 22876) Run 279716 | LS 871 | Orig 0 | GoldenJSON 0
# 22877) Run 279716 | LS 872 | Orig 0 | GoldenJSON 0
# 22878) Run 279716 | LS 873 | Orig 0 | GoldenJSON 0
# 22879) Run 279716 | LS 874 | Orig 0 | GoldenJSON 0
# 24182) Run 279760 | LS 583 | Orig 0 | GoldenJSON 0
# 24183) Run 279760 | LS 584 | Orig 0 | GoldenJSON 0
# 24690) Run 279760 | LS 579 | Orig 0 | GoldenJSON 0
# 24691) Run 279760 | LS 580 | Orig 0 | GoldenJSON 0
# 24692) Run 279760 | LS 581 | Orig 0 | GoldenJSON 0
# 24693) Run 279760 | LS 582 | Orig 0 | GoldenJSON 0
# 26361) Run 280385 | LS 520 | Orig 0 | GoldenJSON 0
# 26362) Run 280385 | LS 521 | Orig 0 | GoldenJSON 0
# 26363) Run 280385 | LS 522 | Orig 0 | GoldenJSON 0
# 28620) Run 279975 | LS 731 | Orig 0 | GoldenJSON 0
# 28621) Run 279975 | LS 732 | Orig 0 | GoldenJSON 0
# 28622) Run 279975 | LS 733 | Orig 0 | GoldenJSON 0
# 29847) Run 279841 | LS 399 | Orig 0 | GoldenJSON 0
# 29848) Run 279841 | LS 400 | Orig 0 | GoldenJSON 0
# 29849) Run 279841 | LS 401 | Orig 0 | GoldenJSON 0
# 29850) Run 279841 | LS 402 | Orig 0 | GoldenJSON 0
# 29851) Run 279841 | LS 403 | Orig 0 | GoldenJSON 0
# 29852) Run 279841 | LS 404 | Orig 0 | GoldenJSON 0
# 29853) Run 279841 | LS 405 | Orig 0 | GoldenJSON 0
# 29861) Run 279841 | LS 406 | Orig 0 | GoldenJSON 0
# 31097) Run 280015 | LS 557 | Orig 0 | GoldenJSON 0
# 31098) Run 280015 | LS 558 | Orig 0 | GoldenJSON 0
# 31099) Run 280015 | LS 559 | Orig 0 | GoldenJSON 0
# 34689) Run 279975 | LS 710 | Orig 0 | GoldenJSON 0
# 34956) Run 279975 | LS 726 | Orig 0 | GoldenJSON 0
# 34957) Run 279975 | LS 727 | Orig 0 | GoldenJSON 0
# 34958) Run 279975 | LS 728 | Orig 0 | GoldenJSON 0
# 34959) Run 279975 | LS 729 | Orig 0 | GoldenJSON 0
# 34960) Run 279975 | LS 730 | Orig 0 | GoldenJSON 0
# 34961) Run 279975 | LS 711 | Orig 0 | GoldenJSON 0
# 34962) Run 279975 | LS 712 | Orig 0 | GoldenJSON 0
# 34963) Run 279975 | LS 713 | Orig 0 | GoldenJSON 0
# 34964) Run 279975 | LS 714 | Orig 0 | GoldenJSON 0
# 34965) Run 279975 | LS 715 | Orig 0 | GoldenJSON 0
# 34979) Run 279975 | LS 716 | Orig 0 | GoldenJSON 0
# 34980) Run 279975 | LS 717 | Orig 0 | GoldenJSON 0
# 34981) Run 279975 | LS 720 | Orig 0 | GoldenJSON 0
# 34982) Run 279975 | LS 718 | Orig 0 | GoldenJSON 0
# 34983) Run 279975 | LS 719 | Orig 0 | GoldenJSON 0
# 34991) Run 279975 | LS 721 | Orig 0 | GoldenJSON 0
# 34992) Run 279975 | LS 722 | Orig 0 | GoldenJSON 0
# 34993) Run 279975 | LS 723 | Orig 0 | GoldenJSON 0
# 34994) Run 279975 | LS 724 | Orig 0 | GoldenJSON 0
# 34995) Run 279975 | LS 725 | Orig 0 | GoldenJSON 0
# 39736) Run 280251 | LS 166 | Orig 0 | GoldenJSON 0
# 40672) Run 280349 | LS 249 | Orig 0 | GoldenJSON 0
# 40673) Run 280349 | LS 250 | Orig 0 | GoldenJSON 0
# 40674) Run 280349 | LS 251 | Orig 0 | GoldenJSON 0
# SinglePhoton_H_background.h5
# Rows: 1680
# 64) Run 282037 | LS 458 | Orig 0 | GoldenJSON 0
# 193) Run 282923 | LS 31 | Orig 0 | GoldenJSON 0
# SinglePhoton_H_signal.h5
# Rows: 22533
# 10516) Run 281707 | LS 983 | Orig 0 | GoldenJSON 0
# 10517) Run 281707 | LS 984 | Orig 0 | GoldenJSON 0
# 10527) Run 281707 | LS 985 | Orig 0 | GoldenJSON 0
# 10528) Run 281707 | LS 986 | Orig 0 | GoldenJSON 0
# 10529) Run 281707 | LS 987 | Orig 0 | GoldenJSON 0
# 10530) Run 281707 | LS 988 | Orig 0 | GoldenJSON 0
# 10531) Run 281707 | LS 989 | Orig 0 | GoldenJSON 0
# 10532) Run 281707 | LS 990 | Orig 0 | GoldenJSON 0
# 10724) Run 281707 | LS 991 | Orig 0 | GoldenJSON 0
# 10725) Run 281707 | LS 992 | Orig 0 | GoldenJSON 0
# 10726) Run 281707 | LS 993 | Orig 0 | GoldenJSON 0
# 10727) Run 281707 | LS 994 | Orig 0 | GoldenJSON 0
# 10728) Run 281707 | LS 995 | Orig 0 | GoldenJSON 0
# 10729) Run 281707 | LS 996 | Orig 0 | GoldenJSON 0
# 11054) Run 281707 | LS 997 | Orig 0 | GoldenJSON 0
# 11055) Run 281707 | LS 998 | Orig 0 | GoldenJSON 0
# 11056) Run 281707 | LS 999 | Orig 0 | GoldenJSON 0
# 11150) Run 283308 | LS 969 | Orig 0 | GoldenJSON 0
# 11151) Run 283308 | LS 970 | Orig 0 | GoldenJSON 0
# 11152) Run 283308 | LS 971 | Orig 0 | GoldenJSON 0
# 12217) Run 283308 | LS 548 | Orig 0 | GoldenJSON 0
# 12222) Run 283308 | LS 572 | Orig 0 | GoldenJSON 0
# 12473) Run 283308 | LS 949 | Orig 0 | GoldenJSON 0
# 12474) Run 283308 | LS 950 | Orig 0 | GoldenJSON 0
# 12475) Run 283308 | LS 951 | Orig 0 | GoldenJSON 0
# 12476) Run 283308 | LS 952 | Orig 0 | GoldenJSON 0
# 12477) Run 283308 | LS 953 | Orig 0 | GoldenJSON 0
# 12478) Run 283308 | LS 954 | Orig 0 | GoldenJSON 0
# 12479) Run 283308 | LS 955 | Orig 0 | GoldenJSON 0
# 12480) Run 283308 | LS 956 | Orig 0 | GoldenJSON 0
# 12481) Run 283308 | LS 957 | Orig 0 | GoldenJSON 0
# 12482) Run 283308 | LS 958 | Orig 0 | GoldenJSON 0
# 12483) Run 283308 | LS 960 | Orig 0 | GoldenJSON 0
# 12484) Run 283308 | LS 961 | Orig 0 | GoldenJSON 0
# 12485) Run 283308 | LS 962 | Orig 0 | GoldenJSON 0
# 12486) Run 283308 | LS 963 | Orig 0 | GoldenJSON 0
# 12487) Run 283308 | LS 964 | Orig 0 | GoldenJSON 0
# 12488) Run 283308 | LS 965 | Orig 0 | GoldenJSON 0
# 12489) Run 283308 | LS 966 | Orig 0 | GoldenJSON 0
# 12490) Run 283308 | LS 967 | Orig 0 | GoldenJSON 0
# 12491) Run 283308 | LS 968 | Orig 0 | GoldenJSON 0
# 14534) Run 283934 | LS 1247 | Orig 0 | GoldenJSON 0
# 14646) Run 283934 | LS 1246 | Orig 0 | GoldenJSON 0
# 14647) Run 283934 | LS 1248 | Orig 0 | GoldenJSON 0
# 14648) Run 283934 | LS 1249 | Orig 0 | GoldenJSON 0
# 14649) Run 283934 | LS 1250 | Orig 0 | GoldenJSON 0
# 14650) Run 283934 | LS 1251 | Orig 0 | GoldenJSON 0
# 14651) Run 283934 | LS 1252 | Orig 0 | GoldenJSON 0
# 14652) Run 283934 | LS 1253 | Orig 0 | GoldenJSON 0
# 14653) Run 283934 | LS 1254 | Orig 0 | GoldenJSON 0
# 15731) Run 283478 | LS 304 | Orig 0 | GoldenJSON 0
# 15732) Run 283478 | LS 305 | Orig 0 | GoldenJSON 0
# 15733) Run 283478 | LS 306 | Orig 0 | GoldenJSON 0
# 15734) Run 283478 | LS 307 | Orig 0 | GoldenJSON 0
# 15735) Run 283478 | LS 308 | Orig 0 | GoldenJSON 0
# 15736) Run 283478 | LS 309 | Orig 0 | GoldenJSON 0
# 15737) Run 283478 | LS 310 | Orig 0 | GoldenJSON 0
# 15738) Run 283478 | LS 311 | Orig 0 | GoldenJSON 0
# 15739) Run 283478 | LS 312 | Orig 0 | GoldenJSON 0
# 15740) Run 283478 | LS 313 | Orig 0 | GoldenJSON 0
# 15741) Run 283478 | LS 314 | Orig 0 | GoldenJSON 0
# 15742) Run 283478 | LS 315 | Orig 0 | GoldenJSON 0
# 15743) Run 283478 | LS 316 | Orig 0 | GoldenJSON 0
# 15744) Run 283478 | LS 317 | Orig 0 | GoldenJSON 0
# 15745) Run 283478 | LS 323 | Orig 0 | GoldenJSON 0
# 15753) Run 283478 | LS 318 | Orig 0 | GoldenJSON 0
# 15754) Run 283478 | LS 319 | Orig 0 | GoldenJSON 0
# 15755) Run 283478 | LS 320 | Orig 0 | GoldenJSON 0
# 15756) Run 283478 | LS 321 | Orig 0 | GoldenJSON 0
# 15757) Run 283478 | LS 322 | Orig 0 | GoldenJSON 0
# 17288) Run 283934 | LS 1264 | Orig 0 | GoldenJSON 0
# 17289) Run 283934 | LS 1265 | Orig 0 | GoldenJSON 0
# 17290) Run 283934 | LS 1266 | Orig 0 | GoldenJSON 0
# 19653) Run 283934 | LS 871 | Orig 0 | GoldenJSON 0
# 19654) Run 283934 | LS 872 | Orig 0 | GoldenJSON 0
# 19655) Run 283934 | LS 873 | Orig 0 | GoldenJSON 0
# 19656) Run 283934 | LS 874 | Orig 0 | GoldenJSON 0
# 19713) Run 283934 | LS 1255 | Orig 0 | GoldenJSON 0
# 19714) Run 283934 | LS 1256 | Orig 0 | GoldenJSON 0
# 19715) Run 283934 | LS 1257 | Orig 0 | GoldenJSON 0
# 19716) Run 283934 | LS 1258 | Orig 0 | GoldenJSON 0
# 19717) Run 283934 | LS 1259 | Orig 0 | GoldenJSON 0
# 19718) Run 283934 | LS 1260 | Orig 0 | GoldenJSON 0
# 19719) Run 283934 | LS 1261 | Orig 0 | GoldenJSON 0
# 19920) Run 283934 | LS 785 | Orig 0 | GoldenJSON 0
# 19921) Run 283934 | LS 786 | Orig 0 | GoldenJSON 0
# 19922) Run 283934 | LS 787 | Orig 0 | GoldenJSON 0
# 19923) Run 283934 | LS 788 | Orig 0 | GoldenJSON 0
# 19941) Run 283934 | LS 789 | Orig 0 | GoldenJSON 0
# 19942) Run 283934 | LS 790 | Orig 0 | GoldenJSON 0
# 19943) Run 283934 | LS 791 | Orig 0 | GoldenJSON 0
# 19944) Run 283934 | LS 792 | Orig 0 | GoldenJSON 0
# Total row count: 128959
# Main dset:
# (128959, 2813)
# CPU times: user 22 s, sys: 4 s, total: 26 s
# Wall time: 25.9 s
